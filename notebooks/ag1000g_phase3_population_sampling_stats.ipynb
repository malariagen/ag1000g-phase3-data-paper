# %%
import pandas as pd
import numpy as np
import seaborn as sns
import gcsfs
from pathlib import Path
import yaml
import dask.array as da
from ag3 import release_data
v3_release = release_data()

# %%
samplesets = v3_release.all_wild_sample_sets

# %%
p3_df = v3_release.load_sample_set_metadata(samplesets, True)
p3_df.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#           partner_sample_id contributor country location  year  month  \
# sample_id
# AR0047-C             LUA047  Joao Pinto  Angola   Luanda  2009      4
# AR0049-C             LUA049  Joao Pinto  Angola   Luanda  2009      4
# AR0051-C             LUA051  Joao Pinto  Angola   Luanda  2009      4
# AR0061-C             LUA061  Joao Pinto  Angola   Luanda  2009      4
# AR0078-C             LUA078  Joao Pinto  Angola   Luanda  2009      4
#
#            latitude  longitude sex_call  sample_set  aim_fraction_colu  \
# sample_id
# AR0047-C     -8.884     13.302        F  AG1000G-AO              0.945
# AR0049-C     -8.884     13.302        F  AG1000G-AO              0.933
# AR0051-C     -8.884     13.302        F  AG1000G-AO              0.937
# AR0061-C     -8.884     13.302        F  AG1000G-AO              0.938
# AR0078-C     -8.884     13.302        F  AG1000G-AO              0.926
#
#            aim_fraction_arab species_gambcolu_arabiensis  \
# sample_id
# AR0047-C               0.001                   gamb_colu
# AR0049-C               0.001                   gamb_colu
# AR0051-C               0.002                   gamb_colu
# AR0061-C               0.002                   gamb_colu
# AR0078-C               0.001                   gamb_colu
#
#           species_gambiae_coluzzii  is_arabiensis  is_gamb_colu  is_gambiae  \
# sample_id
# AR0047-C                  coluzzii          False          True       False
# AR0049-C                  coluzzii          False          True       False
# AR0051-C                  coluzzii          False          True       False
# AR0061-C                  coluzzii          False          True       False
# AR0078-C                  coluzzii          False          True       False
#
#            is_coluzzii
# sample_id
# AR0047-C          True
# AR0049-C          True
# AR0051-C          True
# AR0061-C          True
# AR0078-C          True

# %%
p3_df.tail()
# Out:
#           partner_sample_id      contributor country location  year  month  \
# sample_id
# AC0295-C                K92  Martin Donnelly  Uganda   Kihihi  2012     11
# AC0296-C                K93  Martin Donnelly  Uganda   Kihihi  2012     11
# AC0297-C                K94  Martin Donnelly  Uganda   Kihihi  2012     11
# AC0298-C                K95  Martin Donnelly  Uganda   Kihihi  2012     11
# AC0299-C                K96  Martin Donnelly  Uganda   Kihihi  2012     11
#
#            latitude  longitude sex_call  sample_set  aim_fraction_colu  \
# sample_id
# AC0295-C     -0.751     29.701        F  AG1000G-UG              0.026
# AC0296-C     -0.751     29.701        F  AG1000G-UG              0.029
# AC0297-C     -0.751     29.701        F  AG1000G-UG              0.026
# AC0298-C     -0.751     29.701        F  AG1000G-UG              0.029
# AC0299-C     -0.751     29.701        F  AG1000G-UG              0.029
#
#            aim_fraction_arab species_gambcolu_arabiensis  \
# sample_id
# AC0295-C               0.002                   gamb_colu
# AC0296-C               0.003                   gamb_colu
# AC0297-C               0.002                   gamb_colu
# AC0298-C               0.002                   gamb_colu
# AC0299-C               0.002                   gamb_colu
#
#           species_gambiae_coluzzii  is_arabiensis  is_gamb_colu  is_gambiae  \
# sample_id
# AC0295-C                   gambiae          False          True        True
# AC0296-C                   gambiae          False          True        True
# AC0297-C                   gambiae          False          True        True
# AC0298-C                   gambiae          False          True        True
# AC0299-C                   gambiae          False          True        True
#
#            is_coluzzii
# sample_id
# AC0295-C         False
# AC0296-C         False
# AC0297-C         False
# AC0298-C         False
# AC0299-C         False

# %%
p3_df.head()
# Out:
#           partner_sample_id contributor country location  year  month  \
# sample_id
# AR0047-C             LUA047  Joao Pinto  Angola   Luanda  2009      4
# AR0049-C             LUA049  Joao Pinto  Angola   Luanda  2009      4
# AR0051-C             LUA051  Joao Pinto  Angola   Luanda  2009      4
# AR0061-C             LUA061  Joao Pinto  Angola   Luanda  2009      4
# AR0078-C             LUA078  Joao Pinto  Angola   Luanda  2009      4
#
#            latitude  longitude sex_call  sample_set  aim_fraction_colu  \
# sample_id
# AR0047-C     -8.884     13.302        F  AG1000G-AO              0.945
# AR0049-C     -8.884     13.302        F  AG1000G-AO              0.933
# AR0051-C     -8.884     13.302        F  AG1000G-AO              0.937
# AR0061-C     -8.884     13.302        F  AG1000G-AO              0.938
# AR0078-C     -8.884     13.302        F  AG1000G-AO              0.926
#
#            aim_fraction_arab species_gambcolu_arabiensis  \
# sample_id
# AR0047-C               0.001                   gamb_colu
# AR0049-C               0.001                   gamb_colu
# AR0051-C               0.002                   gamb_colu
# AR0061-C               0.002                   gamb_colu
# AR0078-C               0.001                   gamb_colu
#
#           species_gambiae_coluzzii  is_arabiensis  is_gamb_colu  is_gambiae  \
# sample_id
# AR0047-C                  coluzzii          False          True       False
# AR0049-C                  coluzzii          False          True       False
# AR0051-C                  coluzzii          False          True       False
# AR0061-C                  coluzzii          False          True       False
# AR0078-C                  coluzzii          False          True       False
#
#            is_coluzzii
# sample_id
# AR0047-C          True
# AR0049-C          True
# AR0051-C          True
# AR0061-C          True
# AR0078-C          True

# %%
p2_df = pd.read_csv("../data/ag1000g_phase2_samples.meta.txt", sep="\t")
p2_df.country = p2_df.country.str.replace("France", "Mayotte")
p2_df.head()
# Out:
#     ox_code         src_code population country     location         site  \
# 0  AA0040-C  Twifo_Praso__E2      GHcol   Ghana  Twifo Praso  Twifo Praso
# 1  AA0041-C  Twifo_Praso__H3      GHcol   Ghana  Twifo Praso  Twifo Praso
# 2  AA0042-C      Takoradi_C7      GHcol   Ghana     Takoradi     Takoradi
# 3  AA0043-C      Takoradi_H8      GHcol   Ghana     Takoradi     Takoradi
# 4  AA0044-C     Takoradi_D10      GHcol   Ghana     Takoradi     Takoradi
#
#      contributor        contact  year m_s sex  n_sequences  mean_coverage  \
# 0  David Weetman  David Weetman  2012   M   F     95033368          30.99
# 1  David Weetman  David Weetman  2012   M   F     95843804          31.70
# 2  David Weetman  David Weetman  2012   M   F    107420666          35.65
# 3  David Weetman  David Weetman  2012   M   F     95993752          29.46
# 4  David Weetman  David Weetman  2012   M   F    103044262          33.67
#
#   ebi_sample_acc  latitude  longitude
# 0      ERS311878   5.60858   -1.54926
# 1      ERS311886   5.60858   -1.54926
# 2      ERS311894   4.91217   -1.77397
# 3      ERS311902   4.91217   -1.77397
# 4      ERS311910   4.91217   -1.77397

# %%
#non ox-code samples?
p3_df[p3_df.index.str.contains("VBS", case=False)]
# Out:
#                          partner_sample_id    contributor   country  \
# sample_id
# VBS02039-4431STDY6672907              3227  Nora Besansky  Cameroon
# VBS02040-4431STDY6672908              3245  Nora Besansky  Cameroon
# VBS02041-4431STDY6672909              3284  Nora Besansky  Cameroon
# VBS02042-4431STDY6672910              3308  Nora Besansky  Cameroon
# VBS02043-4431STDY6672911              3310  Nora Besansky  Cameroon
# ...                                    ...            ...       ...
# VBS02119-4431STDY6772831            kl0831  Nora Besansky      Mali
# VBS02121-4431STDY6772832            kl0836  Nora Besansky      Mali
# VBS02127-4431STDY6772833            kl0869  Nora Besansky      Mali
# VBS02129-4431STDY6772835            kl0884  Nora Besansky      Mali
# VBS02130-4431STDY6772836            kl0886  Nora Besansky      Mali
#
#                               location  year  month  latitude  longitude  \
# sample_id
# VBS02039-4431STDY6672907        Birsok  2005     -1     6.997     13.133
# VBS02040-4431STDY6672908  Mabarangal'L  2005     -1     6.915     13.132
# VBS02041-4431STDY6672909         Tekel  2005     -1     6.806     13.174
# VBS02042-4431STDY6672910     Beka Goto  2005     -1     6.751     13.111
# VBS02043-4431STDY6672911     Beka Goto  2005     -1     6.751     13.111
# ...                                ...   ...    ...       ...        ...
# VBS02119-4431STDY6772831          Kela  2004      8    11.880     -8.450
# VBS02121-4431STDY6772832          Kela  2004      8    11.880     -8.450
# VBS02127-4431STDY6772833          Kela  2004      8    11.880     -8.450
# VBS02129-4431STDY6772835          Kela  2004      8    11.880     -8.450
# VBS02130-4431STDY6772836          Kela  2004      8    11.880     -8.450
#
#                          sex_call    sample_set  aim_fraction_colu  \
# sample_id
# VBS02039-4431STDY6672907        F  AG1000G-CM-B              0.025
# VBS02040-4431STDY6672908        F  AG1000G-CM-B              0.038
# VBS02041-4431STDY6672909        F  AG1000G-CM-B              0.034
# VBS02042-4431STDY6672910        F  AG1000G-CM-B              0.037
# VBS02043-4431STDY6672911        F  AG1000G-CM-B              0.028
# ...                           ...           ...                ...
# VBS02119-4431STDY6772831        F  AG1000G-ML-B              0.028
# VBS02121-4431STDY6772832        F  AG1000G-ML-B              0.046
# VBS02127-4431STDY6772833        F  AG1000G-ML-B              0.037
# VBS02129-4431STDY6772835        F  AG1000G-ML-B              0.033
# VBS02130-4431STDY6772836        F  AG1000G-ML-B              0.025
#
#                           aim_fraction_arab species_gambcolu_arabiensis  \
# sample_id
# VBS02039-4431STDY6672907              0.002                   gamb_colu
# VBS02040-4431STDY6672908              0.002                   gamb_colu
# VBS02041-4431STDY6672909              0.003                   gamb_colu
# VBS02042-4431STDY6672910              0.002                   gamb_colu
# VBS02043-4431STDY6672911              0.002                   gamb_colu
# ...                                     ...                         ...
# VBS02119-4431STDY6772831              0.002                   gamb_colu
# VBS02121-4431STDY6772832              0.002                   gamb_colu
# VBS02127-4431STDY6772833              0.002                   gamb_colu
# VBS02129-4431STDY6772835              0.002                   gamb_colu
# VBS02130-4431STDY6772836              0.002                   gamb_colu
#
#                          species_gambiae_coluzzii  is_arabiensis  \
# sample_id
# VBS02039-4431STDY6672907                  gambiae          False
# VBS02040-4431STDY6672908                  gambiae          False
# VBS02041-4431STDY6672909                  gambiae          False
# VBS02042-4431STDY6672910                  gambiae          False
# VBS02043-4431STDY6672911                  gambiae          False
# ...                                           ...            ...
# VBS02119-4431STDY6772831                  gambiae          False
# VBS02121-4431STDY6772832                  gambiae          False
# VBS02127-4431STDY6772833                  gambiae          False
# VBS02129-4431STDY6772835                  gambiae          False
# VBS02130-4431STDY6772836                  gambiae          False
#
#                           is_gamb_colu  is_gambiae  is_coluzzii
# sample_id
# VBS02039-4431STDY6672907          True        True        False
# VBS02040-4431STDY6672908          True        True        False
# VBS02041-4431STDY6672909          True        True        False
# VBS02042-4431STDY6672910          True        True        False
# VBS02043-4431STDY6672911          True        True        False
# ...                                ...         ...          ...
# VBS02119-4431STDY6772831          True        True        False
# VBS02121-4431STDY6772832          True        True        False
# VBS02127-4431STDY6772833          True        True        False
# VBS02129-4431STDY6772835          True        True        False
# VBS02130-4431STDY6772836          True        True        False
#
# [89 rows x 18 columns]

# %% [markdown]
# ## sample sets

# %%
p3_df.sample_set.unique(), len(p3_df.sample_set.unique())
# Out:
# (array(['AG1000G-AO', 'AG1000G-BF-A', 'AG1000G-BF-B', 'AG1000G-BF-C',
#         'AG1000G-CD', 'AG1000G-CF', 'AG1000G-CI', 'AG1000G-CM-A',
#         'AG1000G-CM-B', 'AG1000G-CM-C', 'AG1000G-FR', 'AG1000G-GA-A',
#         'AG1000G-GH', 'AG1000G-GM-A', 'AG1000G-GM-B', 'AG1000G-GM-C',
#         'AG1000G-GN-A', 'AG1000G-GN-B', 'AG1000G-GQ', 'AG1000G-GW',
#         'AG1000G-KE', 'AG1000G-ML-A', 'AG1000G-ML-B', 'AG1000G-MW',
#         'AG1000G-MZ', 'AG1000G-TZ', 'AG1000G-UG'], dtype=object),
#  27)

# %% [markdown]
# ## samples

# %%
#how many samples in phase 3 in total
p3_len = p3_df.shape[0]
p3_len
# Out:
# 2784

# %%
#are there any samples sequenced twice?
p3_df.reset_index(inplace=True)

# %%
#nope
len(p3_df.sample_id.apply(lambda x: x[:8]).unique())
# Out:
# 2784

# %%
#how many samples in phase 2 in total
p2_len = p2_df.shape[0]
p2_len
# Out:
# 1142

# %%
#naively how many new samples in phase 3...
p3_len - p2_len
# Out:
# 1642

# %%
#...but p2 is not actually a subset of p3
#how many samples are "new" to ag1000g in phase 3
p3_unique = np.setdiff1d(p3_df.index, p2_df.ox_code)
len(p3_unique)
# Out:
# 1823

# %%
#how many samples that were in p1 + p2 are missing from phase 3
p2_unique = np.setdiff1d(p2_df.ox_code, p3_df.index)
len(p2_unique)
# Out:
# 181

# %%
p2_unique
# Out:
# array(['AB0085-C', 'AB0089-C', 'AB0094-C', 'AB0095-C', 'AB0097-C',
#        'AB0098-C', 'AB0099-C', 'AB0104-C', 'AB0108-C', 'AB0126-C',
#        'AB0130-C', 'AB0136-C', 'AB0137-C', 'AB0138-C', 'AB0143-C',
#        'AB0146-C', 'AB0148-C', 'AB0150-C', 'AB0151-C', 'AB0155-C',
#        'AB0157-C', 'AB0158-C', 'AB0160-C', 'AB0171-C', 'AB0172-C',
#        'AB0175-C', 'AB0176-C', 'AB0179-C', 'AB0185-C', 'AB0191-C',
#        'AB0195-C', 'AB0201-C', 'AB0202-C', 'AB0219-C', 'AB0227-C',
#        'AB0232-C', 'AB0236-C', 'AB0249-C', 'AB0250-C', 'AB0258-C',
#        'AB0261-C', 'AB0262-C', 'AB0266-C', 'AB0271-C', 'AB0272-C',
#        'AB0273-C', 'AB0280-C', 'AB0281-C', 'AB0282-C', 'AC0089-C',
#        'AC0091-C', 'AC0096-C', 'AC0102-C', 'AC0103-C', 'AC0104-C',
#        'AC0110-C', 'AC0111-C', 'AC0113-C', 'AC0117-C', 'AC0126-C',
#        'AC0128-C', 'AC0134-C', 'AC0138-C', 'AC0144-C', 'AC0145-C',
#        'AC0147-C', 'AC0149-C', 'AC0162-C', 'AC0168-C', 'AC0174-C',
#        'AC0176-C', 'AC0197-C', 'AC0201-C', 'AC0202-C', 'AJ0070-C',
#        'AJ0101-C', 'AK0066-C', 'AK0074-C', 'AK0075-C', 'AK0080-C',
#        'AK0090-C', 'AK0092-C', 'AK0100-C', 'AK0103-C', 'AK0109-C',
#        'AN0017-C', 'AN0025-C', 'AN0026-C', 'AN0061-C', 'AN0063-C',
#        'AN0065-C', 'AN0067-C', 'AN0068-C', 'AN0072-C', 'AN0075-C',
#        'AN0101-C', 'AN0112-C', 'AN0118-C', 'AN0121-C', 'AN0123-C',
#        'AN0125-C', 'AN0127-C', 'AN0132-C', 'AN0134-C', 'AN0135-C',
#        'AN0136-C', 'AN0157-C', 'AN0159-C', 'AN0160-C', 'AN0162-C',
#        'AN0174-C', 'AN0186-C', 'AN0193-C', 'AN0197-C', 'AN0201-C',
#        'AN0202-C', 'AN0203-C', 'AN0210-C', 'AN0222-C', 'AN0224-C',
#        'AN0225-C', 'AN0226-C', 'AN0227-C', 'AN0229-C', 'AN0230-C',
#        'AN0231-C', 'AN0236-C', 'AN0237-C', 'AN0259-C', 'AN0261-C',
#        'AN0263-C', 'AN0267-C', 'AN0282-C', 'AN0283-C', 'AN0284-C',
#        'AN0286-C', 'AN0287-C', 'AN0288-C', 'AN0290-C', 'AN0291-C',
#        'AN0293-C', 'AN0296-C', 'AN0298-C', 'AN0301-C', 'AN0309-C',
#        'AP0014-C', 'AP0017-C', 'AP0018-C', 'AP0024-C', 'AR0010-C',
#        'AR0013-C', 'AR0016-C', 'AR0018-C', 'AR0050-C', 'AR0054-C',
#        'AR0069-C', 'AR0070-C', 'AR0081-C', 'AR0090-C', 'AR0099-C',
#        'AS0002-C', 'AS0008-C', 'AS0014-C', 'AS0015-C', 'AS0019-C',
#        'AS0024-C', 'AS0025-C', 'AS0027-C', 'AS0035-C', 'AS0044-C',
#        'AS0045-C', 'AS0058-C', 'AS0072-C', 'AV0003-C', 'AV0004-C',
#        'AV0029-C', 'AV0030-C', 'AV0034-C', 'AV0042-C', 'AV0044-C',
#        'AV0046-C'], dtype=object)

# %%
#p2_unique seems high, though samples have been dropped fairly evenly across sample sets
p2_unique[0]
# Out:
# 'AB0085-C'

# %%
p2_df[p2_df.ox_code == 'AB0085-C']
# Out:
#      ox_code src_code population       country location  site  contributor  \
# 67  AB0085-C    BF2-4      BFgam  Burkina Faso     Pala  Pala  Austin Burt
#
#            contact  year m_s sex  n_sequences  mean_coverage ebi_sample_acc  \
# 67  Sam O'Loughlin  2012   S   F     89905852          28.01      ERS223996
#
#     latitude  longitude
# 67     11.15     -4.235

# %%
p3_df[p3_df.index == 'AB0085-C']
# Out:
# Empty DataFrame
# Columns: [partner_sample_id, contributor, country, location, year, month, latitude, longitude, sex_call, sample_set, aim_fraction_colu, aim_fraction_arab, species_gambcolu_arabiensis, species_gambiae_coluzzii, is_arabiensis, is_gamb_colu, is_gambiae, is_coluzzii]
# Index: []

# %% [markdown]
# ##### is there an easy way of working out where in the pipeline we lost these samples?

# %% [markdown]
# ## countries

# %%
p2_countries = p2_df.country.unique()
p2_df.country.value_counts(), len(p2_countries)
# Out:
# (Cameroon             297
#  Burkina Faso         167
#  Uganda               112
#  Guinea-Bissau         91
#  Angola                78
#  Cote d'Ivoire         71
#  Gabon                 69
#  Ghana                 67
#  Gambia, The           65
#  Kenya                 48
#  Guinea                44
#  Mayotte               24
#  Equatorial Guinea      9
#  Name: country, dtype: int64,
#  13)

# %%
p3_countries = p3_df.country.unique()
p3_df.country.value_counts(), len(p3_countries)
# Out:
# (Cameroon                        444
#  Tanzania                        300
#  Burkina Faso                    296
#  Uganda                          290
#  Gambia, The                     279
#  Mali                            225
#  Guinea                          136
#  Guinea-Bissau                   101
#  Ghana                           100
#  Kenya                            86
#  Angola                           81
#  Cote d'Ivoire                    80
#  Democratic Republic of Congo     76
#  Mozambique                       74
#  Central African Republic         73
#  Gabon                            69
#  Malawi                           41
#  Mayotte                          23
#  Equatorial Guinea                10
#  Name: country, dtype: int64,
#  19)

# %%
p3_country_unique = np.setdiff1d(p3_countries, p2_countries)
p3_country_unique
# Out:
# array(['Central African Republic', 'Democratic Republic of Congo',
#        'Malawi', 'Mali', 'Mozambique', 'Tanzania'], dtype=object)

# %% [markdown]
# ## sites

# %%
#this gets a bit tricky, some unique lat/lons have multiple sites names (Cameroon iirc)
# use unique lat/lons

# %%
len(p2_df.groupby(["latitude", "longitude"]).size())
# Out:
# 29

# %%
#p3 unique sites (the are 122 "unique" lats AND lons if counted separately) 
len(p3_df.groupby(["latitude", "longitude"]).size())
# Out:
# 124
